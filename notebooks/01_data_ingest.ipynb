# %%
import pandas as pd
import json
from pathlib import Path

# Load one JSONL file (first batch of 100 reports)
file = Path("../data/raw/openfda_page_000.jsonl")

records = []
with file.open("r", encoding="utf-8") as f:
    for line in f:
        records.append(json.loads(line))

# Flatten nested JSON into a DataFrame
df = pd.json_normalize(records)
df.head()
# Out:
#   safetyreportversion safetyreportid primarysourcecountry occurcountry  \
# 0                   2       10003304                   US           US
# 1                   3       10003310                   US           US
# 2                   1       10003349                   US           US
# 3                   3       10003432                   US           US
# 4                   2       10003582                   US           US
#
#   transmissiondateformat transmissiondate reporttype serious  \
# 0                    102         20141212          1       2
# 1                    102         20151125          1       2
# 2                    102         20141002          1       1
# 3                    102         20151125          1       1
# 4                    102         20141002          1       2
#
#   receivedateformat receivedate  ... patient.patientonsetageunit  \
# 0               102    20140312  ...                         NaN
# 1               102    20140312  ...                         801
# 2               102    20140312  ...                         NaN
# 3               102    20140312  ...                         801
# 4               102    20140312  ...                         801
#
#   patient.patientagegroup seriousnesshospitalization seriousnessother  \
# 0                     NaN                        NaN              NaN
# 1                       6                        NaN              NaN
# 2                     NaN                          1                1
# 3                       6                          1              NaN
# 4                     NaN                        NaN              NaN
#
#   patient.patientweight seriousnesslifethreatening  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                  82.1                        NaN
#
#   patient.summary.narrativeincludeclinical seriousnessdeath  \
# 0                                      NaN              NaN
# 1                                      NaN              NaN
# 2                                      NaN              NaN
# 3                                      NaN              NaN
# 4                                      NaN              NaN
#
#   seriousnessdisabling authoritynumb
# 0                  NaN           NaN
# 1                  NaN           NaN
# 2                  NaN           NaN
# 3                  NaN           NaN
# 4                  NaN           NaN
#
# [5 rows x 37 columns]

# %%
# Expand reactions into one row per reaction
rows = []
for rec in records:
    base = {
        "safetyreportid": rec.get("safetyreportid"),
        "receivedate": rec.get("receivedate"),
        "sex": rec.get("patient", {}).get("patientsex"),
        "age": rec.get("patient", {}).get("patientonsetage"),
        "age_unit": rec.get("patient", {}).get("patientonsetageunit"),
        "seriousnessdeath": rec.get("seriousnessdeath"),
        "seriousnesshospitalization": rec.get("seriousnesshospitalization"),
    }

    # reactions (list of dicts)
    for reaction in rec.get("patient", {}).get("reaction", []):
        row = base.copy()
        row["reaction"] = reaction.get("reactionmeddrapt")
        rows.append(row)

df_clean = pd.DataFrame(rows)
df_clean.head(10)
# Out:
#   safetyreportid receivedate sex   age age_unit seriousnessdeath  \
# 0       10003304    20140312   2  None     None             None
# 1       10003310    20140312   2    66      801             None
# 2       10003349    20140312   2  None     None             None
# 3       10003349    20140312   2  None     None             None
# 4       10003349    20140312   2  None     None             None
# 5       10003432    20140312   2    84      801             None
# 6       10003432    20140312   2    84      801             None
# 7       10003582    20140312   1    58      801             None
# 8       10003582    20140312   1    58      801             None
# 9       10003582    20140312   1    58      801             None
#
#   seriousnesshospitalization                  reaction
# 0                       None     Drug hypersensitivity
# 1                       None                 Back pain
# 2                          1  Cerebrovascular accident
# 3                          1  Blood pressure increased
# 4                          1                      Pain
# 5                          1         Oedema peripheral
# 6                          1           Fluid retention
# 7                       None              Hypertension
# 8                       None               Dehydration
# 9                       None              Night sweats

# %%
df_clean["reaction"].value_counts().head(20)
# Out:
# reaction
# Rash                            9
# Drug interaction                8
# Dizziness                       7
# Type 2 diabetes mellitus        7
# Fatigue                         7
# Pain                            6
# Headache                        6
# Insomnia                        5
# Weight increased                5
# Dyspnoea                        5
# Nausea                          5
# Diarrhoea                       5
# Haemoglobin decreased           5
# Gastrointestinal haemorrhage    5
# Hypertension                    5
# Contusion                       4
# Oedema peripheral               4
# Drug administration error       4
# Platelet count decreased        3
# Blood count abnormal            3
# Name: count, dtype: int64

# %%
out_path = Path("../data/processed/aspirin_clean.csv")
df_clean.to_csv(out_path, index=False)
print(f"Saved cleaned data to {out_path}")
# Out:
# Saved cleaned data to ../data/processed/aspirin_clean.csv
